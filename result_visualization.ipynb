# %% [markdown]
# # Result Visualization

# %% [markdown]
# This file plots experiment run results for analysis.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from utility import get_datetime_id

# %%
get_datetime_id()
# Out:
# '06042024190401'

# %%
df = pd.read_csv("./__run_metrics/ttt.csv", converters={'session_timestamp': str})
df
# Out:
#    world_type player1 player2  outcome  avg_milliseconds_per_move_player1  \
# 0         ttt       X       O        1                           0.000000
# 1         ttt       X       O        2                           0.000000
# 2         ttt       X       O        1                           0.000000
# 3         ttt       X       O        1                           0.000000
# 4         ttt       X       O        1                           0.249390
# 5         ttt       X       O        0                           0.000000
# 6         ttt       X       O        1                           0.000000
# 7         ttt       X       O        2                           0.000000
# 8         ttt       X       O        1                           0.000000
# 9         ttt       X       O        1                           0.000000
# 10        ttt       X       O        0                           0.000000
# 11        ttt       X       O        1                           0.000000
# ...
